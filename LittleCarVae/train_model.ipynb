# %%
from ProcessedImage import ProcessedImage
imgs = list(ProcessedImage.from_dir('..\\Data'))
[str(img) for img in imgs[0:10]]
# Out:
# ['ProcessedImage for ..\\Data\\DougsCars\\20171220_213158911_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213245412_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213256286_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213305258_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213315432_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213325306_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213336280_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\DougsCars\\20171220_213349323_iOS.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\LittleCarDb1\\SF0836-001_1.jpg (0 in cache)',
#  'ProcessedImage for ..\\Data\\LittleCarDb1\\SF0836-002_1.jpg (0 in cache)']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2, 10, sharey=True, figsize=(8,1.5))
ProcessedImage.image_strip(imgs, axes)
